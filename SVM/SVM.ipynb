# %% [markdown]
# # Task
# Load the dataset "IRIS.csv", train a Support Vector Machine model on it, and visualize the results.

# %% [markdown]
# ## Load the dataset
#
# ### Subtask:
# Load the `IRIS.csv` file into a pandas DataFrame.

# %% [markdown]
# **Reasoning**:
# Import pandas and load the CSV file into a DataFrame.

# %%
import pandas as pd

df = pd.read_csv('IRIS.csv')

# %% [markdown]
# **Reasoning**:
# Display the first few rows of the DataFrame to verify the data loading.

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ## Prepare the data
#
# ### Subtask:
# Separate the features (X) and the target variable (y).

# %% [markdown]
# **Reasoning**:
# Separate the features (X) and the target variable (y) from the DataFrame.

# %%
X = df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
y = df['species']

# %% [markdown]
# ## Split the data
#
# ### Subtask:
# Split the data into training and testing sets.

# %% [markdown]
# **Reasoning**:
# Split the features `X` and target variable `y` into training and testing sets using `train_test_split`.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %% [markdown]
# ## Train the svm model
#
# ### Subtask:
# Train a Support Vector Machine classifier on the training data.

# %% [markdown]
# **Reasoning**:
# Import the SVC class and train the model.

# %%
from sklearn.svm import SVC

svc_model = SVC()
svc_model.fit(X_train, y_train)
# Out:
# SVC()

# %% [markdown]
# ## Evaluate the model
#
# ### Subtask:
# Evaluate the performance of the trained model on the testing data.

# %% [markdown]
# **Reasoning**:
# Evaluate the performance of the trained SVC model on the test data using accuracy, classification report, and confusion matrix.

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

y_pred = svc_model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.4f}')

print('\nClassification Report:')
print(classification_report(y_test, y_pred))

conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Accuracy: 1.0000
#
# Classification Report:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        15
# Iris-versicolor       1.00      1.00      1.00        11
#  Iris-virginica       1.00      1.00      1.00        12
#
#        accuracy                           1.00        38
#       macro avg       1.00      1.00      1.00        38
#    weighted avg       1.00      1.00      1.00        38

# %% [markdown]
# ## Visualize the results
#
# ### Subtask:
# Visualize the classification results, potentially using a confusion matrix or by plotting the decision boundary if applicable.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The SVM model trained on the Iris dataset achieved an accuracy of 1.0000 on the test set.
# *   The classification report showed perfect precision, recall, and F1-score (1.00) for all three classes (Iris-setosa, Iris-versicolor, and Iris-virginica).
# *   The confusion matrix indicated no misclassifications, with all test instances correctly classified.
#
# ### Insights or Next Steps
#
# *   The SVM model performed perfectly on the test data, suggesting strong generalization to unseen data from the same distribution.
# *   While direct visualization of the 4-dimensional decision boundary is not feasible, examining the confusion matrix provides clear insight into the model's classification performance for each class.
